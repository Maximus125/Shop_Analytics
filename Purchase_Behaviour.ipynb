# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/Abhi_Dell/Documents/Internships/Quantium/QVI_purchase_behaviour.csv')

# %%
df.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
df.info()   #No Null Values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#        LYLTY_CARD_NBR
# count    7.263700e+04
# mean     1.361859e+05
# std      8.989293e+04
# min      1.000000e+03
# 25%      6.620200e+04
# 50%      1.340400e+05
# 75%      2.033750e+05
# max      2.373711e+06

# %%
df['PREMIUM_CUSTOMER'].value_counts()
# Out:
# Mainstream    29245
# Budget        24470
# Premium       18922
# Name: PREMIUM_CUSTOMER, dtype: int64

# %%
df['LIFESTAGE'].value_counts()
# Out:
# RETIREES                  14805
# OLDER SINGLES/COUPLES     14609
# YOUNG SINGLES/COUPLES     14441
# OLDER FAMILIES             9780
# YOUNG FAMILIES             9178
# MIDAGE SINGLES/COUPLES     7275
# NEW FAMILIES               2549
# Name: LIFESTAGE, dtype: int64

# %%
sns.countplot(y='LIFESTAGE', data=df);

# %%
sns.countplot(y='PREMIUM_CUSTOMER', data=df);

# %%
df.groupby('LIFESTAGE')['PREMIUM_CUSTOMER'].value_counts()
# Out:
# LIFESTAGE               PREMIUM_CUSTOMER
# MIDAGE SINGLES/COUPLES  Mainstream          3340
#                         Premium             2431
#                         Budget              1504
# NEW FAMILIES            Budget              1112
#                         Mainstream           849
#                         Premium              588
# OLDER FAMILIES          Budget              4675
#                         Mainstream          2831
#                         Premium             2274
# OLDER SINGLES/COUPLES   Mainstream          4930
#                         Budget              4929
#                         Premium             4750
# RETIREES                Mainstream          6479
#                         Budget              4454
#                         Premium             3872
# YOUNG FAMILIES          Budget              4017
#                         Mainstream          2728
#                         Premium             2433
# ...

# %%
df.groupby('LIFESTAGE')['PREMIUM_CUSTOMER'].value_counts().plot(figsize=((15,15)), kind='barh');

# %%
df.to_csv('Purchase1.csv')
